# %%
def func_xinchao():
    print('Xin chào Hiếu : \n'*10)

func_xinchao()

# %%
def func_x(x):
    print(x*x)
func_x(5)

# %%
def func_2parameter(a,b):
    return (a + b)

total = func_2parameter(1,4)

print(f'Tổng a + b = {total}')

# %%
square = lambda x : x**2
print(square(5))

# %%
tong = lambda a,b : a+b 
print(tong(10,11))

# %%
class People():
    def __init__(self,name,age,height,weight):
        self.name = name
        self.age = age 
        self.height = height
        self.weight = weight
    
    def info_people(self):
        return(f'Tôi tên là {self.name} , tôi {self.age} tuổi , chiều cao {int(self.height)/10} , nặng {self.weight}')
    
    def get_BMI (self):
        return self.weight / (self.height** 2)
    
    def your_dream (self,kg):
        return f'Cân nặng của tôi hiện tại là {self.weight} kg và tôi muốn giảm về {kg} kg'
    
    

people_1 = People('Hiếu',24,178,86)
print(f'{people_1.info_people()}')
print(f'Số BMI của tôi là : {people_1.get_BMI()}')

print(people_1.your_dream(70))

# %%
a = 5 
b = 0
ket_qua=0
try:
    ket_qua = a / 0
except ZeroDivisionError:
    print('Không thể chia số cho 0 ')
    #raise ZeroDivisionError('Không thể chia hết cho  0 ') # dừng chạy

finally:
    print('Xử lý hoàn thành')

# %%
class Inventory():
    def __init__(self,namesp,giasp,masp):
        self.namesp=namesp
        self.giasp=giasp
        self.masp=masp

    def info_inventory(self):
        return f'Mã sp : {self.masp} có giá là {self.giasp}'
        
Inventory('Sữa tiệt trùng',50000,'MI01')
print(Inventory.info_inventory())
