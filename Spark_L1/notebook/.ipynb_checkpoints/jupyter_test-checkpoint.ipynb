# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .master("spark://mindx-master:7077") \
    .appName("DockerJupyterSpark") \
    .getOrCreate()

# Kiểm tra Spark đã chạy
print(spark.version)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[14], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder \
#       3     .master("spark://172.20.0.2:7077") \
#       4     .appName("DockerJupyterSpark") \
#       5     .getOrCreate()
#       7 # Kiểm tra Spark đã chạy
#       8 print(spark.version)
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/sql/session.py:500, in SparkSession.Builder.getOrCreate(self)
#     497     sc = SparkContext.getOrCreate(sparkConf)
#     498     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     499     # by all sessions.
# --> 500     session = SparkSession(sc, options=self._options)
#     501 else:
#     502     getattr(
#     503         getattr(session._jvm, "SparkSession$"), "MODULE$"
#     504     ).applyModifiableSettings(session._jsparkSession, self._options)
#
# File /usr/local/lib/python3.8/dist-packages/pyspark/sql/session.py:589, in SparkSession.__init__(self, sparkContext, jsparkSession, options)
#     585         getattr(getattr(self._jvm, "SparkSession$"), "MODULE$").applyModifiableSettings(
#     586             jsparkSession, options
#     587         )
#     588     else:
# --> 589         jsparkSession = self._jvm.SparkSession(self._jsc.sc(), options)
#     590 else:
#     591     getattr(getattr(self._jvm, "SparkSession$"), "MODULE$").applyModifiableSettings(
#     592         jsparkSession, options
#     593     )
#
# File /usr/local/lib/python3.8/dist-packages/py4j/java_gateway.py:1627, in JavaClass.__call__(self, *args)
#    1621 command = proto.CONSTRUCTOR_COMMAND_NAME +\
#    1622     self._command_header +\
#    1623     args_command +\
#    1624     proto.END_COMMAND_PART
#    1626 answer = self._gateway_client.send_command(command)
# -> 1627 return_value = get_return_value(
#    1628     answer, self._gateway_client, None, self._fqn)
#    1630 for temp_arg in temp_args:
#    1631     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/lib/python3.8/dist-packages/py4j/protocol.py:327, in get_return_value(answer, gateway_client, target_id, name)
#     325 value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     326 if answer[1] == REFERENCE_TYPE:
# --> 327     raise Py4JJavaError(
#     328         "An error occurred while calling {0}{1}{2}.\n".
#     329         format(target_id, ".", name), value)
#     330 else:
#     331     raise Py4JError(
#     332         "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     333         format(target_id, ".", name, value))
#
# Py4JJavaError: An error occurred while calling None.org.apache.spark.sql.SparkSession.
# : java.lang.IllegalStateException: Cannot call methods on a stopped SparkContext.
# This stopped SparkContext was created at:
#
# org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:58)
# java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(Unknown Source)
# java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(Unknown Source)
# java.base/java.lang.reflect.Constructor.newInstance(Unknown Source)
# py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# py4j.Gateway.invoke(Gateway.java:238)
# py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# java.base/java.lang.Thread.run(Unknown Source)
#
# The currently active SparkContext was created at:
#
# (No active SparkContext.)
#
# 	at org.apache.spark.SparkContext.assertNotStopped(SparkContext.scala:122)
# 	at org.apache.spark.sql.SparkSession.<init>(SparkSession.scala:113)
# 	at org.apache.spark.sql.SparkSession.<init>(SparkSession.scala:106)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(Unknown Source)
# 	at java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(Unknown Source)
# 	at java.base/java.lang.reflect.Constructor.newInstance(Unknown Source)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# 	at py4j.Gateway.invoke(Gateway.java:238)
# 	at py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# 	at py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# 	at py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# 	at py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# 	at java.base/java.lang.Thread.run(Unknown Source)

# %%
df = spark.read.csv("/opt/spark-data/tips.csv", header=True, inferSchema=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = spark.read.csv("/opt/spark-data/tips.csv", header=True, inferSchema=True)
#
# NameError: name 'spark' is not defined

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.show()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv('/opt/spark-data/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from pyspark.sql import SparkSession
import pandas as pd
import numpy as np
import random

data = {
    "id_du_an": range(1, 501),
    "ten_du_an": [f"Cong trinh {i}" for i in range(1, 501)],
    "loai_vat_lieu": [random.choice(["Thep", "Xi mang", "Cat", "Da", "Gach"]) for _ in range(500)],
    "nha_thau": [random.choice(["Delta", "Coteccons", "Hoa Binh", "Vinaconex", "An Phong"]) for _ in range(500)],
    "gia_tri_goi_thau": np.random.randint(1000, 50000, 500), # Đơn vị: Triệu VNĐ
    "so_luong_vat_lieu": np.random.randint(100, 10000, 500),
    "don_gia": np.random.randint(10, 500, 500),
    "ngay_bat_dau": pd.to_datetime(['2024-01-01'] * 500) + pd.to_timedelta(np.random.randint(0, 365, 500), unit='D'),
    "trang_thai": [random.choice(["Dang thi cong", "Hoan thanh", "Tam dung", "Cho duyet"]) for _ in range(500)],
    "khu_vuc": [random.choice(["Mien Bac", "Mien Trung", "Mien Nam"]) for _ in range(500)]
}
pdf = pd.DataFrame(data)

# Chuyển từ Pandas DataFrame sang Spark DataFrame
df = spark.createDataFrame(pdf)

# Hiển thị 5 dòng đầu tiên
df.show(5)
# Out:
# [Stage 6:>                                                          (0 + 1) / 1]
# +--------+------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+--------+
# |id_du_an|   ten_du_an|loai_vat_lieu| nha_thau|gia_tri_goi_thau|so_luong_vat_lieu|don_gia|       ngay_bat_dau|   trang_thai| khu_vuc|
# +--------+------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+--------+
# |       1|Cong trinh 1|         Thep|    Delta|           25221|             1732|    443|2024-12-24 00:00:00|    Cho duyet|Mien Nam|
# |       2|Cong trinh 2|          Cat|Vinaconex|           29669|             4411|     86|2024-04-25 00:00:00|   Hoan thanh|Mien Nam|
# |       3|Cong trinh 3|         Gach| An Phong|           15187|             6091|    215|2024-04-16 00:00:00|Dang thi cong|Mien Nam|
# |       4|Cong trinh 4|      Xi mang| An Phong|           31248|             9527|    309|2024-11-11 00:00:00|Dang thi cong|Mien Nam|
# |       5|Cong trinh 5|          Cat|    Delta|           13085|              470|     30|2024-08-28 00:00:00|     Tam dung|Mien Nam|
# +--------+------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+--------+
# only showing top 5 rows

# %%
spark.sql("SELECT * FROM bang_xay_dung").show()
# Out:
# +--------+-------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+----------+
# |id_du_an|    ten_du_an|loai_vat_lieu| nha_thau|gia_tri_goi_thau|so_luong_vat_lieu|don_gia|       ngay_bat_dau|   trang_thai|   khu_vuc|
# +--------+-------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+----------+
# |       1| Cong trinh 1|         Thep|    Delta|           25221|             1732|    443|2024-12-24 00:00:00|    Cho duyet|  Mien Nam|
# |       2| Cong trinh 2|          Cat|Vinaconex|           29669|             4411|     86|2024-04-25 00:00:00|   Hoan thanh|  Mien Nam|
# |       3| Cong trinh 3|         Gach| An Phong|           15187|             6091|    215|2024-04-16 00:00:00|Dang thi cong|  Mien Nam|
# |       4| Cong trinh 4|      Xi mang| An Phong|           31248|             9527|    309|2024-11-11 00:00:00|Dang thi cong|  Mien Nam|
# |       5| Cong trinh 5|          Cat|    Delta|           13085|              470|     30|2024-08-28 00:00:00|     Tam dung|  Mien Nam|
# |       6| Cong trinh 6|          Cat|Coteccons|            9618|             2932|    477|2024-09-03 00:00:00|    Cho duyet|  Mien Nam|
# |       7| Cong trinh 7|         Thep| An Phong|           30870|             1997|    155|2024-06-23 00:00:00|Dang thi cong|  Mien Bac|
# |       8| Cong trinh 8|         Thep|    Delta|           39080|             3824|    364|2024-03-28 00:00:00|    Cho duyet|  Mien Bac|
# |       9| Cong trinh 9|         Thep|    Delta|           39676|             8184|    293|2024-06-24 00:00:00|    Cho duyet|  Mien Bac|
# |      10|Cong trinh 10|          Cat| An Phong|           40047|              784|    195|2024-02-27 00:00:00|   Hoan thanh|  Mien Nam|
# |      11|Cong trinh 11|         Thep| Hoa Binh|           39990|             3334|    339|2024-11-21 00:00:00|Dang thi cong|  Mien Bac|
# |      12|Cong trinh 12|      Xi mang|    Delta|            9649|             8065|    381|2024-12-07 00:00:00|     Tam dung|  Mien Bac|
# |      13|Cong trinh 13|           Da| Hoa Binh|           49252|             1766|    136|2024-09-12 00:00:00|   Hoan thanh|  Mien Nam|
# |      14|Cong trinh 14|         Thep| Hoa Binh|            9973|             7313|    295|2024-01-16 00:00:00|     Tam dung|Mien Trung|
# |      15|Cong trinh 15|           Da| Hoa Binh|           17769|             9413|    118|2024-04-03 00:00:00|    Cho duyet|Mien Trung|
# |      16|Cong trinh 16|         Thep|Vinaconex|           30090|             8087|    422|2024-08-09 00:00:00|   Hoan thanh|Mien Trung|
# |      17|Cong trinh 17|           Da|Coteccons|           39100|             4473|    467|2024-10-31 00:00:00|     Tam dung|  Mien Nam|
# |      18|Cong trinh 18|      Xi mang|    Delta|           16467|             6878|    155|2024-05-23 00:00:00|Dang thi cong|  Mien Bac|
# |      19|Cong trinh 19|           Da| Hoa Binh|           46799|             2062|    215|2024-03-27 00:00:00|     Tam dung|Mien Trung|
# |      20|Cong trinh 20|         Gach| An Phong|           14345|             5441|    117|2024-04-06 00:00:00|     Tam dung|Mien Trung|
# +--------+-------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+----------+
# only showing top 20 rows

# %%
spark.sql("SELECT * FROM bang_xay_dung WHERE loai_vat_lieu IN ('Thep', 'Xi mang') ORDER BY gia_tri_goi_thau DESC LIMIT 5").show()
# Out:
# +--------+--------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+----------+
# |id_du_an|     ten_du_an|loai_vat_lieu| nha_thau|gia_tri_goi_thau|so_luong_vat_lieu|don_gia|       ngay_bat_dau|   trang_thai|   khu_vuc|
# +--------+--------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+----------+
# |      24| Cong trinh 24|      Xi mang|Coteccons|           49821|             5256|    438|2024-01-25 00:00:00|    Cho duyet|  Mien Nam|
# |     128|Cong trinh 128|         Thep|    Delta|           49777|             6419|     16|2024-08-22 00:00:00|Dang thi cong|  Mien Nam|
# |      91| Cong trinh 91|      Xi mang|Coteccons|           49752|             1286|    472|2024-01-21 00:00:00|   Hoan thanh|Mien Trung|
# |     378|Cong trinh 378|         Thep|    Delta|           49710|             4136|    190|2024-05-11 00:00:00|    Cho duyet|  Mien Nam|
# |      56| Cong trinh 56|         Thep|    Delta|           49260|             3735|    413|2024-04-06 00:00:00|     Tam dung|  Mien Nam|
# +--------+--------------+-------------+---------+----------------+-----------------+-------+-------------------+-------------+----------+
